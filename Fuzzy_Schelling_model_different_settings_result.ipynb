# %% [markdown]
# # A Fuzzy Set Extension of Schelling's Spatial Segregation Model
# # (Ishida, 2023, Journal of Computational Social Science, https://doi.org/10.1007/s42001-023-00234-7)
# ## Results of diﬀerent settings
# ### Atsushi Ishida (aishida@kwansei.ac.jp)

# %%
import fuzzy_Schelling_utils as fs
import numpy as np
import matplotlib.pyplot as plt
plt.style.use(['default'])
plt.rcParams["font.size"] = 12
# random seed
np.random.seed(8931)

# %%
# Global parameters
NUM_ROW = 50
NUM_COL = 50
NUM_TRIALS = 200
PERCENT_SIMILAR_WANTED = [0.3, 0.5, 0.7]
DENSITY = [0.3, 0.5, 0.7]
labels = ["h = 0.000", "h = 0.469", "h = 0.722", "h = 0.881", "h = 0.971", "h = 1.000"]

# %% [markdown]
# # Single run

# %% [markdown]
# ## Uniform

# %%
fig = plt.figure(figsize=(16, 10))
dst_subfigs = fig.subfigures(1, len(DENSITY))

for i, dst_subfig in enumerate(dst_subfigs):
    psw_subfigs = dst_subfig.subfigures(1, len(PERCENT_SIMILAR_WANTED))
    for j, psw_subfig in enumerate(psw_subfigs):
        ax = psw_subfig.subplots(3, 1)

        unhappy_percent_trend, average_similarity_trend, average_fuzzy_trend = fs.trial_for_h(
            NUM_ROW = NUM_ROW,
            NUM_COL = NUM_COL,
            DENSITY = DENSITY[i],
            PERCENT_SIMILAR_WANTED = PERCENT_SIMILAR_WANTED[j],
            NUM_TRIALS = NUM_TRIALS,
            ALPHA = 1,
            BETA = 1
            )

        t = len(unhappy_percent_trend)
        ax[0].plot(np.arange(t), unhappy_percent_trend, label=labels)
        ax[1].plot(np.arange(t), average_similarity_trend, label=labels)
        ax[2].plot(np.arange(t), average_fuzzy_trend, label=labels)
        ax[0].set_ylim([-0.005, 1.005])
        ax[1].set_ylim([0.5, 1])
        ax[2].set_ylim([0, 1])
        ax[0].set_xlim([0, 200])
        ax[1].set_xlim([0, 200])
        ax[2].set_xlim([0, 200])
        ax[0].axes.xaxis.set_ticklabels([])
        ax[1].axes.xaxis.set_ticklabels([])
        ax[0].set_title("d = " + str(DENSITY[i]) + "\n" +
                        "p = " + str(PERCENT_SIMILAR_WANTED[j]))
        if (i == 0 and j == 0):
            ax[0].set_ylabel("% unhappy")
            ax[1].set_ylabel("similarity")
            ax[2].set_ylabel("fuzziness")
        if not (i == 0 and j == 0):
            ax[0].axes.yaxis.set_ticklabels([])
            ax[1].axes.yaxis.set_ticklabels([])
            ax[2].axes.yaxis.set_ticklabels([])

plt.subplots_adjust(hspace=0.2, wspace=0.2, bottom=0.05)

lines, labels = ax[0].get_legend_handles_labels()
fig.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, 0),  borderaxespad=0, ncol=6)
plt.savefig('TeX/trends_for_h_uniform_dist.pdf',bbox_inches='tight')
plt.show();

# %% [markdown]
# ## Unimodal

# %%
fig = plt.figure(figsize=(16, 10))
dst_subfigs = fig.subfigures(1, len(DENSITY))

for i, dst_subfig in enumerate(dst_subfigs):
    psw_subfigs = dst_subfig.subfigures(1, len(PERCENT_SIMILAR_WANTED))
    for j, psw_subfig in enumerate(psw_subfigs):
        ax = psw_subfig.subplots(3, 1)

        unhappy_percent_trend, average_similarity_trend, average_fuzzy_trend = fs.trial_for_h(
            NUM_ROW = NUM_ROW,
            NUM_COL = NUM_COL,
            DENSITY = DENSITY[i],
            PERCENT_SIMILAR_WANTED = PERCENT_SIMILAR_WANTED[j],
            NUM_TRIALS = NUM_TRIALS,
            ALPHA = 2,
            BETA = 2
            )

        t = len(unhappy_percent_trend)
        ax[0].plot(np.arange(t), unhappy_percent_trend, label=labels)
        ax[1].plot(np.arange(t), average_similarity_trend, label=labels)
        ax[2].plot(np.arange(t), average_fuzzy_trend, label=labels)
        ax[0].set_ylim([-0.005, 1.005])
        ax[1].set_ylim([0.5, 1])
        ax[2].set_ylim([0, 1])
        ax[0].set_xlim([0, 200])
        ax[1].set_xlim([0, 200])
        ax[2].set_xlim([0, 200])
        ax[0].axes.xaxis.set_ticklabels([])
        ax[1].axes.xaxis.set_ticklabels([])
        ax[0].set_title("d = " + str(DENSITY[i]) + "\n" +
                        "p = " + str(PERCENT_SIMILAR_WANTED[j]))
        if (i == 0 and j == 0):
            ax[0].set_ylabel("% unhappy")
            ax[1].set_ylabel("similarity")
            ax[2].set_ylabel("fuzziness")
        if not (i == 0 and j == 0):
            ax[0].axes.yaxis.set_ticklabels([])
            ax[1].axes.yaxis.set_ticklabels([])
            ax[2].axes.yaxis.set_ticklabels([])

plt.subplots_adjust(hspace=0.2, wspace=0.2, bottom=0.05)

lines, labels = ax[0].get_legend_handles_labels()
fig.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, 0),  borderaxespad=0, ncol=6)
# plt.savefig('TeX/trends_for_h_unimodal_dist.pdf',bbox_inches='tight')
plt.show();

# %% [markdown]
# ## Bimodal

# %%
fig = plt.figure(figsize=(16, 10))
dst_subfigs = fig.subfigures(1, len(DENSITY))

for i, dst_subfig in enumerate(dst_subfigs):
    psw_subfigs = dst_subfig.subfigures(1, len(PERCENT_SIMILAR_WANTED))
    for j, psw_subfig in enumerate(psw_subfigs):
        ax = psw_subfig.subplots(3, 1)

        unhappy_percent_trend, average_similarity_trend, average_fuzzy_trend = fs.trial_for_h(
            NUM_ROW = NUM_ROW,
            NUM_COL = NUM_COL,
            DENSITY = DENSITY[i],
            PERCENT_SIMILAR_WANTED = PERCENT_SIMILAR_WANTED[j],
            NUM_TRIALS = NUM_TRIALS,
            ALPHA = 0.5,
            BETA = 0.5
            )

        t = len(unhappy_percent_trend)
        ax[0].plot(np.arange(t), unhappy_percent_trend, label=labels)
        ax[1].plot(np.arange(t), average_similarity_trend, label=labels)
        ax[2].plot(np.arange(t), average_fuzzy_trend, label=labels)
        ax[0].set_ylim([-0.005, 1.005])
        ax[1].set_ylim([0.5, 1])
        ax[2].set_ylim([0, 1])
        ax[0].set_xlim([0, 200])
        ax[1].set_xlim([0, 200])
        ax[2].set_xlim([0, 200])
        ax[0].axes.xaxis.set_ticklabels([])
        ax[1].axes.xaxis.set_ticklabels([])
        ax[0].set_title("d = " + str(DENSITY[i]) + "\n" +
                        "p = " + str(PERCENT_SIMILAR_WANTED[j]))
        if (i == 0 and j == 0):
            ax[0].set_ylabel("% unhappy")
            ax[1].set_ylabel("similarity")
            ax[2].set_ylabel("fuzziness")
        if not (i == 0 and j == 0):
            ax[0].axes.yaxis.set_ticklabels([])
            ax[1].axes.yaxis.set_ticklabels([])
            ax[2].axes.yaxis.set_ticklabels([])

plt.subplots_adjust(hspace=0.2, wspace=0.2, bottom=0.05)

lines, labels = ax[0].get_legend_handles_labels()
fig.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, 0),  borderaxespad=0, ncol=6)
# plt.savefig('TeX/trends_for_h_bimodal_dist.pdf',bbox_inches='tight')
plt.show();

# %% [markdown]
# ## Simple Schelling

# %%
fig = plt.figure(figsize=(16, 10))
dst_subfigs = fig.subfigures(1, len(DENSITY))

for i, dst_subfig in enumerate(dst_subfigs):
    psw_subfigs = dst_subfig.subfigures(1, len(PERCENT_SIMILAR_WANTED))
    for j, psw_subfig in enumerate(psw_subfigs):
        ax = psw_subfig.subplots(3, 1)

        unhappy_percent_trend, average_similarity_trend, average_fuzzy_trend = fs.trial_simple_Schelling(
            NUM_ROW = NUM_ROW,
            NUM_COL = NUM_COL,
            DENSITY = DENSITY[i],
            PERCENT_SIMILAR_WANTED = PERCENT_SIMILAR_WANTED[j],
            NUM_TRIALS = NUM_TRIALS,
            )

        t = len(unhappy_percent_trend)
        ax[0].plot(np.arange(t), unhappy_percent_trend, label=labels)
        ax[1].plot(np.arange(t), average_similarity_trend, label=labels)
        ax[2].plot(np.arange(t), average_fuzzy_trend, label=labels)
        ax[0].set_ylim([-0.005, 1.005])
        ax[1].set_ylim([0.5, 1])
        ax[2].set_ylim([0, 1])
        ax[0].set_xlim([0, 200])
        ax[1].set_xlim([0, 200])
        ax[2].set_xlim([0, 200])
        ax[0].axes.xaxis.set_ticklabels([])
        ax[1].axes.xaxis.set_ticklabels([])
        ax[0].set_title("d = " + str(DENSITY[i]) + "\n" +
                        "p = " + str(PERCENT_SIMILAR_WANTED[j]))
        if (i == 0 and j == 0):
            ax[0].set_ylabel("% unhappy")
            ax[1].set_ylabel("similarity")
            ax[2].set_ylabel("fuzziness")
        if not (i == 0 and j == 0):
            ax[0].axes.yaxis.set_ticklabels([])
            ax[1].axes.yaxis.set_ticklabels([])
            ax[2].axes.yaxis.set_ticklabels([])

plt.subplots_adjust(hspace=0.2, wspace=0.2, bottom=0.05)
# plt.savefig('TeX/trends_simple_Schelling.pdf',bbox_inches='tight')
plt.show();

# %% [markdown]
# # Multiple runs

# %% [markdown]
# Warning: the following code might take a long time to run!

# %%
# number of simulation runs
NUM_RUN = 100

# %% [markdown]
# ## Uniform

# %%
fig = plt.figure(figsize=(16, 10))
dst_subfigs = fig.subfigures(1, len(DENSITY))

for i, dst_subfig in enumerate(dst_subfigs):
    psw_subfigs = dst_subfig.subfigures(1, len(PERCENT_SIMILAR_WANTED))
    for j, psw_subfig in enumerate(psw_subfigs):
        ax = psw_subfig.subplots(3, 1)

        unhappy_percent_trends = []
        average_similarity_trends = []
        average_fuzzy_trends = []

        for run in range(NUM_RUN):

            unhappy_percent_trend, average_similarity_trend, average_fuzzy_trend = fs.trial_for_h(
                NUM_ROW = NUM_ROW,
                NUM_COL = NUM_COL,
                DENSITY = DENSITY[i],
                PERCENT_SIMILAR_WANTED = PERCENT_SIMILAR_WANTED[j],
                NUM_TRIALS = NUM_TRIALS,
                ALPHA = 1,
                BETA = 1
                )

            # If the equilibrium is reached before the 200th time, the last value is filled to the 200th time.
            for index in (unhappy_percent_trend, average_similarity_trend, average_fuzzy_trend):
                for t in range(len(index), NUM_TRIALS + 1):
                    index.append(index[-1])

            unhappy_percent_trends.append(unhappy_percent_trend)
            average_similarity_trends.append(average_similarity_trend)
            average_fuzzy_trends.append(average_fuzzy_trend)

        unhappy_percent_means = np.array(unhappy_percent_trends)[:,::50,:].mean(axis=0)
        unhappy_percent_stds = np.array(unhappy_percent_trends)[:,::50,:].std(axis=0)
        average_similarity_means = np.array(average_similarity_trends)[:,::50,:].mean(axis=0)
        average_similarity_stds = np.array(average_similarity_trends)[:,::50,:].std(axis=0)
        average_fuzzy_means = np.array(average_fuzzy_trends)[:,::50,:].mean(axis=0)
        average_fuzzy_stds = np.array(average_fuzzy_trends)[:,::50,:].std(axis=0)

        for k in range(6):
            ax[0].errorbar(np.arange(0, 201,50), unhappy_percent_means[:,k], yerr=unhappy_percent_stds[:,k], capsize=3, linestyle='--', marker='o', markersize=4, label=labels[k])
        for k in range(6):
            ax[1].errorbar(np.arange(0, 201,50), average_similarity_means[:,k], yerr=average_similarity_stds[:,k], capsize=3, linestyle='--', marker='o', markersize=4, label=labels[k])
        for k in range(6):
            ax[2].errorbar(np.arange(0, 201,50), average_fuzzy_means[:,k], yerr=average_fuzzy_stds[:,k], capsize=3, linestyle='--', marker='o', markersize=4, label=labels[k])
        ax[0].set_ylim([-0.005, 1.005])
        ax[1].set_ylim([0.5, 1])
        ax[2].set_ylim([0, 1])
        ax[0].set_xlim([-10, 210])
        ax[1].set_xlim([-10, 210])
        ax[2].set_xlim([-10, 210])
        ax[0].axes.xaxis.set_ticks([0,100,200])
        ax[0].axes.xaxis.set_ticklabels([])
        ax[1].axes.xaxis.set_ticks([0,100,200])
        ax[1].axes.xaxis.set_ticklabels([])
        ax[2].axes.xaxis.set_ticks([0,100,200])
        ax[0].set_title("d = " + str(DENSITY[i]) + "\n" +
                        "p = " + str(PERCENT_SIMILAR_WANTED[j]))
        if (i == 0 and j == 0):
            ax[0].set_ylabel("% unhappy")
            ax[1].set_ylabel("similarity")
            ax[2].set_ylabel("fuzziness")
        if not (i == 0 and j == 0):
            ax[0].axes.yaxis.set_ticklabels([])
            ax[1].axes.yaxis.set_ticklabels([])
            ax[2].axes.yaxis.set_ticklabels([])

plt.subplots_adjust(hspace=0.2, wspace=0.2, bottom=0.05)

lines, labels = ax[0].get_legend_handles_labels()
fig.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, 0),  borderaxespad=0, ncol=6)
# plt.savefig('TeX/multi_trends_for_h_uniform_dist.pdf',bbox_inches='tight')
plt.show();

# %% [markdown]
# ## Unimodal

# %%
fig = plt.figure(figsize=(16, 10))
dst_subfigs = fig.subfigures(1, len(DENSITY))

for i, dst_subfig in enumerate(dst_subfigs):
    psw_subfigs = dst_subfig.subfigures(1, len(PERCENT_SIMILAR_WANTED))
    for j, psw_subfig in enumerate(psw_subfigs):
        ax = psw_subfig.subplots(3, 1)

        unhappy_percent_trends = []
        average_similarity_trends = []
        average_fuzzy_trends = []

        for run in range(NUM_RUN):

            unhappy_percent_trend, average_similarity_trend, average_fuzzy_trend = fs.trial_for_h(
                NUM_ROW = NUM_ROW,
                NUM_COL = NUM_COL,
                DENSITY = DENSITY[i],
                PERCENT_SIMILAR_WANTED = PERCENT_SIMILAR_WANTED[j],
                NUM_TRIALS = NUM_TRIALS,
                ALPHA = 2,
                BETA = 2
                )

            # If the equilibrium is reached before the 200th time, the last value is filled to the 200th time.
            for index in (unhappy_percent_trend, average_similarity_trend, average_fuzzy_trend):
                for t in range(len(index), NUM_TRIALS + 1):
                    index.append(index[-1])

            unhappy_percent_trends.append(unhappy_percent_trend)
            average_similarity_trends.append(average_similarity_trend)
            average_fuzzy_trends.append(average_fuzzy_trend)

        unhappy_percent_means = np.array(unhappy_percent_trends)[:,::50,:].mean(axis=0)
        unhappy_percent_stds = np.array(unhappy_percent_trends)[:,::50,:].std(axis=0)
        average_similarity_means = np.array(average_similarity_trends)[:,::50,:].mean(axis=0)
        average_similarity_stds = np.array(average_similarity_trends)[:,::50,:].std(axis=0)
        average_fuzzy_means = np.array(average_fuzzy_trends)[:,::50,:].mean(axis=0)
        average_fuzzy_stds = np.array(average_fuzzy_trends)[:,::50,:].std(axis=0)

        for k in range(6):
            ax[0].errorbar(np.arange(0, 201,50), unhappy_percent_means[:,k], yerr=unhappy_percent_stds[:,k], capsize=3, linestyle='--', marker='o', markersize=4, label=labels[k])
        for k in range(6):
            ax[1].errorbar(np.arange(0, 201,50), average_similarity_means[:,k], yerr=average_similarity_stds[:,k], capsize=3, linestyle='--', marker='o', markersize=4, label=labels[k])
        for k in range(6):
            ax[2].errorbar(np.arange(0, 201,50), average_fuzzy_means[:,k], yerr=average_fuzzy_stds[:,k], capsize=3, linestyle='--', marker='o', markersize=4, label=labels[k])
        ax[0].set_ylim([-0.005, 1.005])
        ax[1].set_ylim([0.5, 1])
        ax[2].set_ylim([0, 1])
        ax[0].set_xlim([-10, 210])
        ax[1].set_xlim([-10, 210])
        ax[2].set_xlim([-10, 210])
        ax[0].axes.xaxis.set_ticks([0,100,200])
        ax[0].axes.xaxis.set_ticklabels([])
        ax[1].axes.xaxis.set_ticks([0,100,200])
        ax[1].axes.xaxis.set_ticklabels([])
        ax[2].axes.xaxis.set_ticks([0,100,200])
        ax[0].set_title("d = " + str(DENSITY[i]) + "\n" +
                        "p = " + str(PERCENT_SIMILAR_WANTED[j]))
        if (i == 0 and j == 0):
            ax[0].set_ylabel("% unhappy")
            ax[1].set_ylabel("similarity")
            ax[2].set_ylabel("fuzziness")
        if not (i == 0 and j == 0):
            ax[0].axes.yaxis.set_ticklabels([])
            ax[1].axes.yaxis.set_ticklabels([])
            ax[2].axes.yaxis.set_ticklabels([])

plt.subplots_adjust(hspace=0.2, wspace=0.2, bottom=0.05)

lines, labels = ax[0].get_legend_handles_labels()
fig.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, 0),  borderaxespad=0, ncol=6)
# plt.savefig('TeX/multi_trends_for_h_unimodal_dist.pdf',bbox_inches='tight')
plt.show();

# %% [markdown]
# ## Bimodal

# %%
fig = plt.figure(figsize=(16, 10))
dst_subfigs = fig.subfigures(1, len(DENSITY))

for i, dst_subfig in enumerate(dst_subfigs):
    psw_subfigs = dst_subfig.subfigures(1, len(PERCENT_SIMILAR_WANTED))
    for j, psw_subfig in enumerate(psw_subfigs):
        ax = psw_subfig.subplots(3, 1)

        unhappy_percent_trends = []
        average_similarity_trends = []
        average_fuzzy_trends = []

        for run in range(NUM_RUN):

            unhappy_percent_trend, average_similarity_trend, average_fuzzy_trend = fs.trial_for_h(
                NUM_ROW = NUM_ROW,
                NUM_COL = NUM_COL,
                DENSITY = DENSITY[i],
                PERCENT_SIMILAR_WANTED = PERCENT_SIMILAR_WANTED[j],
                NUM_TRIALS = NUM_TRIALS,
                ALPHA = 0.5,
                BETA = 0.5
                )

            # If the equilibrium is reached before the 200th time, the last value is filled to the 200th time.
            for index in (unhappy_percent_trend, average_similarity_trend, average_fuzzy_trend):
                for t in range(len(index), NUM_TRIALS + 1):
                    index.append(index[-1])

            unhappy_percent_trends.append(unhappy_percent_trend)
            average_similarity_trends.append(average_similarity_trend)
            average_fuzzy_trends.append(average_fuzzy_trend)

        unhappy_percent_means = np.array(unhappy_percent_trends)[:,::50,:].mean(axis=0)
        unhappy_percent_stds = np.array(unhappy_percent_trends)[:,::50,:].std(axis=0)
        average_similarity_means = np.array(average_similarity_trends)[:,::50,:].mean(axis=0)
        average_similarity_stds = np.array(average_similarity_trends)[:,::50,:].std(axis=0)
        average_fuzzy_means = np.array(average_fuzzy_trends)[:,::50,:].mean(axis=0)
        average_fuzzy_stds = np.array(average_fuzzy_trends)[:,::50,:].std(axis=0)

        for k in range(6):
            ax[0].errorbar(np.arange(0, 201,50), unhappy_percent_means[:,k], yerr=unhappy_percent_stds[:,k], capsize=3, linestyle='--', marker='o', markersize=4, label=labels[k])
        for k in range(6):
            ax[1].errorbar(np.arange(0, 201,50), average_similarity_means[:,k], yerr=average_similarity_stds[:,k], capsize=3, linestyle='--', marker='o', markersize=4, label=labels[k])
        for k in range(6):
            ax[2].errorbar(np.arange(0, 201,50), average_fuzzy_means[:,k], yerr=average_fuzzy_stds[:,k], capsize=3, linestyle='--', marker='o', markersize=4, label=labels[k])
        ax[0].set_ylim([-0.005, 1.005])
        ax[1].set_ylim([0.5, 1])
        ax[2].set_ylim([0, 1])
        ax[0].set_xlim([-10, 210])
        ax[1].set_xlim([-10, 210])
        ax[2].set_xlim([-10, 210])
        ax[0].axes.xaxis.set_ticks([0,100,200])
        ax[0].axes.xaxis.set_ticklabels([])
        ax[1].axes.xaxis.set_ticks([0,100,200])
        ax[1].axes.xaxis.set_ticklabels([])
        ax[2].axes.xaxis.set_ticks([0,100,200])
        ax[0].set_title("d = " + str(DENSITY[i]) + "\n" +
                        "p = " + str(PERCENT_SIMILAR_WANTED[j]))
        if (i == 0 and j == 0):
            ax[0].set_ylabel("% unhappy")
            ax[1].set_ylabel("similarity")
            ax[2].set_ylabel("fuzziness")
        if not (i == 0 and j == 0):
            ax[0].axes.yaxis.set_ticklabels([])
            ax[1].axes.yaxis.set_ticklabels([])
            ax[2].axes.yaxis.set_ticklabels([])

plt.subplots_adjust(hspace=0.2, wspace=0.2, bottom=0.05)

lines, labels = ax[0].get_legend_handles_labels()
fig.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, 0),  borderaxespad=0, ncol=6)
# plt.savefig('TeX/multi_trends_for_h_bimodal_dist.pdf',bbox_inches='tight')
plt.show();
